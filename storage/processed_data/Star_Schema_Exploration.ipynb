# %%
import duckdb

conn = duckdb.connect('kcc_queries_processed.duckdb')

conn.execute("SHOW TABLES").fetch_df()
# Out:
#              name
# 0    dim_category
# 1  dim_demography
# 2      dim_sector
# 3     fct_queries

# %%
conn.execute("SELECT * FROM fct_queries LIMIT 5").fetch_df()
# Out:
#          query_id              created_on  state_id  category_id  sector_id  \
# 0  h4BTf1ve7dkmpQ 2021-04-17 17:53:35.217         8           10          1
# 1  keBlbHnPs2c62w 2023-12-24 10:46:17.500         8           10          1
# 2  UfSfB7B2lQxh2Q 2022-12-21 11:57:18.513         8           10          1
# 3  N1u9IJeYeVsAxg 2022-12-11 11:08:04.457         8           10          1
# 4  7fx4oM4TsIdpsg 2021-02-25 10:48:07.707         8           10          1
#
#            crop               query_type  \
# 0          Guar         Plant Protection
# 1       Barseem       Cultural Practices
# 2       Barseem       Cultural Practices
# 3  Napier Grass  Sowing Time and Weather
# 4  Napier Grass                    Seeds
#
#                                           query_text  \
# 0                                 yellowing in leafs
# 1  farmer want more information about Barseem fod...
# 2  farmer wants to know information about varieti...
# 3  Farmer Wants To Know Information About Sowing ...
# 4  Farmer want information regarding the contact ...
#
#                                              kcc_ans
# 0  गुआर मे पीलापन की समस्या के लिए Mancozeb 75% W...
# 1  किसान भाई बरसीम  की फसल की खेती करते समय निम्न...
# 2  प्रिय किसान भाई चारे वाली फसल बरसीम की खेती के...
# 3  प्रिय किसान भाई  नेपियर घास  लगाने का उपयुक्त ...
# 4  प्रिय किसान भाई नपियर घास उपलब्धता से सम्बंधित...
